# %%
# pandas read contenst/1/metadata.csv
import pandas as pd
df = pd.read_csv('contests/1/metadata.csv')


# show orient column, filename column
df[['Rotation', 'FileName', 'Model', 'ImageWidth', 'ImageHeight', 'Orientation']]
# Out:
#                Rotation             FileName              Model  ImageWidth  \
# 0   Horizontal (Normal)        IMG_0102.HEIC  iPhone 16 Pro Max        4032
# 1                   NaN  20240920_144415.jpg   Galaxy S24 Ultra        4000
# 2                   NaN  20240920_191313.jpg   Galaxy S24 Ultra        4000
# 3   Horizontal (Normal)        IMG_0036.HEIC  iPhone 16 Pro Max        4032
# 4                   NaN  20240920_191258.jpg   Galaxy S24 Ultra        4000
# 5   Horizontal (Normal)        IMG_0105.HEIC  iPhone 16 Pro Max        4032
# 6   Horizontal (Normal)        IMG_0037.heic  iPhone 16 Pro Max        3024
# 7                   NaN  20240920_144338.jpg   Galaxy S24 Ultra        4000
# 8   Horizontal (Normal)        IMG_0034.HEIC  iPhone 16 Pro Max        5712
# 9                   NaN  20240920_144446.jpg   Galaxy S24 Ultra        4000
# 10                  NaN  20240920_144331.jpg   Galaxy S24 Ultra        4000
# ...

# %%
# print df columns all
for col in df.columns:
    print(col)
# Out:
# GreenTRC
# TemporalIDNested
# MPImage2
# ProfileVersion
# PhotosAppFeatureFlags
# ProfileDescriptionML-it-IT
# AccelerationVector
# ModifyDate
# ChromaFormat
# AFPerformance
# SubSecDateTimeOriginal
# ChromaticAdaptation
# ProfileDescriptionML-sk-SK
# DeviceAttributes
# MPFVersion
# RegionAreaH
# Make
# AToB0
# CompositeImageCount
# SubSecCreateDate
# EmbeddedImageName
# TimeStamp
# ImageWidth
# EncodingProcess
# GPSHPositioningError
# MediaDataOffset
# RegionExtensions
# RunTimeValue
# LensDistortionCenterOffsetY
# ConstraintIndicatorFlags
# GPSImgDirectionRef
# AuxiliaryImageType
# FocusPosition
# _dt
# DepthMapHeight
# BitDepthChroma
# SceneType
# ProfileConnectionSpace
# FileName
# FileModifyDate
# StoredFormat
# ImageCaptureType
# BlueMatrixColumn
# ImageHeight
# GPSImgDirection
# FNumber
# ResolutionUnit
# YResolution
# ProfileDescriptionML-es-ES
# Match
# Orientation
# ProfileDescriptionML-tr-TR
# Filtered
# VideoFullRangeFlag
# GPSLongitude
# SensingMethod
# ...

# %%
def load_metadata():
    return pd.read_csv('./contests/1/metadata.csv')

metadata = load_metadata()

metadata[metadata['FileName'] == "IMG_0102.HEIC"]["Orientation"].values[0]
# Out:
# 'Rotate 90 CW'
